# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.kdeplot(df['ConvertedComp'])
# Add labels to x and y axes
plt.xlabel('Converted Compensation')
plt.ylabel('Density')

# Set the title of the plot
plt.title('KDE of Converted Compensation')

# Display the plot
plt.show()

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
plt.hist(df['ConvertedComp'], bins=50, edgecolor='black')  
plt.xlabel('Converted Compensation')
plt.ylabel('Frequency')
plt.title('Histogram of Converted Compensation')
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
count_man_responders = df[df["Gender"] == "Man"].shape[0]
print("Number of responders who identified as Man:", count_man_responders)
# Out:
# Number of responders who identified as Man: 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
median_convertedcomp_woman = df[df["Gender"] == "Woman"]["ConvertedComp"].median()
print("Median ConvertedComp of responders identified as Woman:", median_convertedcomp_woman)
# Out:
# Median ConvertedComp of responders identified as Woman: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
Age_5_summary = df["Age"].describe().loc[['min','25%','50%','75%','max']]
Age_5_summary
# Out:
# min    16.0
# 25%    25.0
# 50%    29.0
# 75%    35.0
# max    99.0
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
plt.hist(df['Age'], bins=50)  # Adjust the number of bins as needed
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
sns.boxplot(df['ConvertedComp'])
# Out:
# <AxesSubplot:xlabel='ConvertedComp'>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
q1 = df['ConvertedComp'].quantile(0.25)
q3 = df['ConvertedComp'].quantile(0.75)

IQR = q3 - q1
print('IQR', IQR)
# Out:
# Q1 26868.0
# Q3 100000.0
# IQR 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
upper_bound = q3 + IQR*1.5
print('Upper bound:', upper_bound)

lower_bound = q1 - IQR*1.5
print('Lower bound:', lower_bound)
# Out:
# Upper bound: 209698.0
# Lower bound: -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# The lower bound is negative, and ConvertedComp column does not contain any negative value, so we estimate only the upper outliers
has_negative_values = (df["ConvertedComp"] < 0).any()

if has_negative_values:
    print("The 'ConvertedComp' column contains negative values.")
else:
    print("The 'ConvertedComp' column does not contain negative values.")
outliers = 0
high_out = df[df["ConvertedComp"] >upper_bound].shape[0]
print("The number of outliers is:" + str(high_out) )
# Out:
# The 'ConvertedComp' column does not contain negative values.
# The number of outliers is:879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
new_df = df[(df["ConvertedComp"] >= lower_bound) & (df["ConvertedComp"] <= upper_bound)]
new_df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp  WorkWeekHrs   CodeRevHrs  \
# count   9703.000000  9.703000e+03    9703.000000  9664.000000  7612.000000
# mean   12501.007317  7.241139e+05   59883.208389    41.864782     4.737455
# std     7235.627217  7.186806e+06   43394.336755    24.613489     4.420472
# min        4.000000  0.000000e+00       0.000000     3.000000     0.000000
# 25%     6237.000000  2.000000e+04   24060.000000    40.000000     2.000000
# 50%    12571.000000  6.300000e+04   52704.000000    40.000000     4.000000
# 75%    18787.500000  1.150000e+05   85574.500000    42.000000     5.000000
# max    25141.000000  3.900000e+08  209356.000000  1012.000000    99.000000
#
#                Age
# count  9493.000000
# mean     30.695860
# std       7.346625
# min      16.000000
# 25%      25.000000
# 50%      29.000000
# 75%      34.000000
# max      99.000000

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr()["Age"]
# Out:
# Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Age              1.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
